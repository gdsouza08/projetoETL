# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['**', '###!', '####', '****', '*****', 'NULL']
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates = ['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                  NaN     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                  NaN     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PARÁ DE MINAS            MG                  NaN     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 0        12:00:00                    0 NaN          NaN          NaN
# 1        11:05:00                    0 NaN          NaN          NaN
# 2        03:00:00                    0 NaN          NaN          NaN
# 3        17:30:00                    0 NaN          NaN          NaN
# 4        19:25:00                    0 NaN          NaN          NaN
# 5        17:53:00                    0 NaN          NaN          NaN
# 6        18:40:00                    0 NaN          NaN          NaN
# 7        12:30:00                    3 NaN          NaN          NaN
# 8        23:15:00                    2 NaN          NaN          NaN
# 9        20:00:00                    0 NaN          NaN          NaN
#
#    Unnamed: 12 Unnamed: 13
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo":pa.Column(pa.Int, required=False),
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2, 2), nullable=True),
        "ocorrencia_aerodromo":pa.Column(pa.String, nullable=True),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 6109              RECIFE            PE                 SBRF     2021-08-15
# 6110         PORTO VELHO            RO                 SBPV     2021-08-16
# 6111               BELÉM            PA                 SBBE     2021-08-17
# 6112          DOM AQUINO            MT                  NaN     2021-08-18
# 6113            CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 0           12:00:00                    0 NaN          NaN          NaN
# 1           11:05:00                    0 NaN          NaN          NaN
# 2           03:00:00                    0 NaN          NaN          NaN
# 3           17:30:00                    0 NaN          NaN          NaN
# 4           19:25:00                    0 NaN          NaN          NaN
# ...              ...                  ...  ..          ...          ...
# 6109        15:05:00                    0 NaN          NaN          NaN
# 6110        02:30:00                    0 NaN          NaN          NaN
# 6111        15:45:00                    0 NaN          NaN          NaN
# 6112        16:00:00                    0 NaN          NaN          NaN
# 6113        12:45:00                    0 NaN          NaN          NaN
#
#       Unnamed: 12 Unnamed: 13
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN
# ...           ...         ...
# 6109          NaN         NaN
# 6110          NaN         NaN
# 6111          NaN         NaN
# 6112          NaN         NaN
# 6113          NaN         NaN
#
# [6114 rows x 14 columns]

# %% [markdown]
# pegando a ultima linha

# %%
df.iloc[-1]
# Out:
# codigo_ocorrencia                         80259
# codigo_ocorrencia2                        80259
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                      CAMPINAS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBKP
# ocorrencia_dia              2021-08-18 00:00:00
# ocorrencia_hora                        12:45:00
# total_recomendacoes                           0
#                                             NaN
# Unnamed: 10                                 NaN
# Unnamed: 11                                 NaN
# Unnamed: 12                                 NaN
# Unnamed: 13                                 NaN
# Name: 6113, dtype: object

# %%
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 10        21:30:00                    0 NaN          NaN          NaN
# 11        14:50:00                    8 NaN          NaN          NaN
# 12        03:00:00                    0 NaN          NaN          NaN
# 13        17:00:00                    2 NaN          NaN          NaN
# 14        14:30:00                    0 NaN          NaN          NaN
#
#     Unnamed: 12 Unnamed: 13
# 10          NaN         NaN
# 11          NaN         NaN
# 12          NaN         NaN
# 13          NaN         NaN
# 14          NaN         NaN

# %% [markdown]
# busca de dados de uma coluna

# %%
df.loc[:, "ocorrencia_uf"]
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %%
df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %% [markdown]
# localizar onde está o valor nulo

# %%
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
# 5855              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 5855      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 2227        02:54:00                    0 NaN          NaN          NaN
# 5855        11:00:00                    0 NaN          NaN          NaN
#
#       Unnamed: 12 Unnamed: 13
# 2227          NaN         NaN
# 5855          NaN         NaN

# %% [markdown]
# listar total dos valores sem contas os nulos

# %%
df.count()
# Out:
# codigo_ocorrencia           6114
# codigo_ocorrencia2          6114
# ocorrencia_classificacao    6114
# ocorrencia_cidade           6114
# ocorrencia_uf               6112
# ocorrencia_aerodromo        3658
# ocorrencia_dia              6114
# ocorrencia_hora             6113
# total_recomendacoes         6114
#                                0
# Unnamed: 10                    0
# Unnamed: 11                    0
# Unnamed: 12                    0
# Unnamed: 13                    1
# dtype: int64

# %%
#ocorrencias com mais de 10 recomendacoes

filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2797              52265               52265                 ACIDENTE
# 3932              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# 326         RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
# 530              SÃO PAULO            SP                  NaN     2010-12-14
# 727               ITÁPOLIS            SP                 SDIO     2011-04-09
# 872                 RECIFE            PE                 SBRF     2011-07-13
# 884   SÃO JOSÉ DOS PINHAIS            PR                 SBCT     2011-07-15
# 1062            UBERLÂNDIA            MG                 SBUL     2011-11-15
# 1972              BRASÍLIA            DF                 SBBR     2013-04-13
# 2797                SANTOS            SP                  NaN     2014-08-13
# 3932               VITÓRIA            ES                  NaN     2017-02-21
#
#      ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 63          20:07:00                   11 NaN          NaN          NaN
# 326         12:26:00                   19 NaN          NaN          NaN
# 530         20:15:00                   11 NaN          NaN          NaN
# 727         14:50:00                   11 NaN          NaN          NaN
# 872         09:54:00                   23 NaN          NaN          NaN
# 884         17:05:00                   11 NaN          NaN          NaN
# 1062        02:15:00                   20 NaN          NaN          NaN
# 1972        18:00:00                   11 NaN          NaN          NaN
# 2797        13:03:00                   13 NaN          NaN          NaN
# 3932        11:47:00                   12 NaN          NaN          NaN
#
#       Unnamed: 12 Unnamed: 13
# 63            NaN         NaN
# 326           NaN         NaN
# 530           NaN         NaN
# 727           NaN         NaN
# 872           NaN         NaN
# 884           NaN         NaN
# 1062          NaN         NaN
# 1972          NaN         NaN
# 2797          NaN         NaN
# 3932          NaN         NaN

# %%
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade']]
# Out:
#          ocorrencia_cidade
# 63               SÃO PAULO
# 326         RIO DE JANEIRO
# 530              SÃO PAULO
# 727               ITÁPOLIS
# 872                 RECIFE
# 884   SÃO JOSÉ DOS PINHAIS
# 1062            UBERLÂNDIA
# 1972              BRASÍLIA
# 2797                SANTOS
# 3932               VITÓRIA

# %%
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'	
df.loc[filtro, ['ocorrencia_classificacao', 'ocorrencia_cidade']]
# Out:
#      ocorrencia_classificacao ocorrencia_cidade
# 7             INCIDENTE GRAVE          CANUTAMA
# 8             INCIDENTE GRAVE          CASCAVEL
# 9             INCIDENTE GRAVE     PARÁ DE MINAS
# 29            INCIDENTE GRAVE          CURITIBA
# 35            INCIDENTE GRAVE            PALMAS
# ...                       ...               ...
# 6090          INCIDENTE GRAVE             MARAÚ
# 6095          INCIDENTE GRAVE   ELDORADO DO SUL
# 6097          INCIDENTE GRAVE     CAXIAS DO SUL
# 6098          INCIDENTE GRAVE   CHAPADÃO DO SUL
# 6104          INCIDENTE GRAVE       VOTUPORANGA
#
# [791 rows x 2 columns]

# %%
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'	
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2, ['ocorrencia_classificacao', 'ocorrencia_cidade', 'ocorrencia_uf']]
# Out:
#      ocorrencia_classificacao      ocorrencia_cidade ocorrencia_uf
# 136           INCIDENTE GRAVE           PIRASSUNUNGA            SP
# 171           INCIDENTE GRAVE              GUARULHOS            SP
# 219           INCIDENTE GRAVE              SÃO PAULO            SP
# 297           INCIDENTE GRAVE              SÃO PAULO            SP
# 314           INCIDENTE GRAVE  SÃO JOSÉ DO RIO PRETO            SP
# ...                       ...                    ...           ...
# 5949          INCIDENTE GRAVE          FERNANDÓPOLIS            SP
# 6000          INCIDENTE GRAVE                   LINS            SP
# 6007          INCIDENTE GRAVE              SÃO PAULO            SP
# 6081          INCIDENTE GRAVE      BRAGANÇA PAULISTA            SP
# 6104          INCIDENTE GRAVE            VOTUPORANGA            SP
#
# [145 rows x 3 columns]

# %%
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'	
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2, ['ocorrencia_classificacao', 'ocorrencia_cidade', 'ocorrencia_uf']]
# Out:
#      ocorrencia_classificacao  ocorrencia_cidade ocorrencia_uf
# 7             INCIDENTE GRAVE           CANUTAMA            AM
# 8             INCIDENTE GRAVE           CASCAVEL            PR
# 9             INCIDENTE GRAVE      PARÁ DE MINAS            MG
# 11                   ACIDENTE          SÃO PAULO            SP
# 16                  INCIDENTE          SÃO PAULO            SP
# ...                       ...                ...           ...
# 6097          INCIDENTE GRAVE      CAXIAS DO SUL            RS
# 6098          INCIDENTE GRAVE    CHAPADÃO DO SUL            MS
# 6104          INCIDENTE GRAVE        VOTUPORANGA            SP
# 6108                INCIDENTE  BRAGANÇA PAULISTA            SP
# 6113                INCIDENTE           CAMPINAS            SP
#
# [2110 rows x 3 columns]

# %%
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE ')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2, ['ocorrencia_classificacao', 'ocorrencia_cidade', 'ocorrencia_uf']]
# Out:
#      ocorrencia_classificacao      ocorrencia_cidade ocorrencia_uf
# 136           INCIDENTE GRAVE           PIRASSUNUNGA            SP
# 171           INCIDENTE GRAVE              GUARULHOS            SP
# 219           INCIDENTE GRAVE              SÃO PAULO            SP
# 297           INCIDENTE GRAVE              SÃO PAULO            SP
# 314           INCIDENTE GRAVE  SÃO JOSÉ DO RIO PRETO            SP
# ...                       ...                    ...           ...
# 5949          INCIDENTE GRAVE          FERNANDÓPOLIS            SP
# 6000          INCIDENTE GRAVE                   LINS            SP
# 6007          INCIDENTE GRAVE              SÃO PAULO            SP
# 6081          INCIDENTE GRAVE      BRAGANÇA PAULISTA            SP
# 6104          INCIDENTE GRAVE            VOTUPORANGA            SP
#
# [145 rows x 3 columns]

# %%
filtro1 = df.ocorrencia_classificacao.isin (['INCIDENTE GRAVE', 'INCIDENTE']) 
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2, ['ocorrencia_classificacao', 'ocorrencia_cidade', 'ocorrencia_uf']]
# Out:
#      ocorrencia_classificacao  ocorrencia_cidade ocorrencia_uf
# 16                  INCIDENTE          SÃO PAULO            SP
# 18                  INCIDENTE             SANTOS            SP
# 26                  INCIDENTE           SOROCABA            SP
# 27                  INCIDENTE           CAMPINAS            SP
# 33                  INCIDENTE          GUARULHOS            SP
# ...                       ...                ...           ...
# 6084                INCIDENTE          SÃO PAULO            SP
# 6085                INCIDENTE          SÃO PAULO            SP
# 6104          INCIDENTE GRAVE        VOTUPORANGA            SP
# 6108                INCIDENTE  BRAGANÇA PAULISTA            SP
# 6113                INCIDENTE           CAMPINAS            SP
#
# [1058 rows x 3 columns]

# %%
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro, [ 'ocorrencia_cidade','ocorrencia_uf']]
# Out:
#      ocorrencia_cidade ocorrencia_uf
# 6                COARI            AM
# 7             CANUTAMA            AM
# 8             CASCAVEL            PR
# 15            CANUTAMA            AM
# 20     CRUZEIRO DO SUL            AC
# ...                ...           ...
# 6094          CURITIBA            PR
# 6097     CAXIAS DO SUL            RS
# 6098   CHAPADÃO DO SUL            MS
# 6100           CORUMBÁ            MS
# 6113          CAMPINAS            SP
#
# [895 rows x 2 columns]

# %%
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro, [ 'ocorrencia_cidade','ocorrencia_uf']]
# Out:
#       ocorrencia_cidade ocorrencia_uf
# 7              CANUTAMA            AM
# 12             BRASÍLIA            DF
# 15             CANUTAMA            AM
# 25           UBERLÂNDIA            MG
# 26             SOROCABA            SP
# ...                 ...           ...
# 6093           UMUARAMA            PR
# 6094           CURITIBA            PR
# 6102            GOIÂNIA            GO
# 6104        VOTUPORANGA            SP
# 6108  BRAGANÇA PAULISTA            SP
#
# [1642 rows x 2 columns]

# %%
filtro = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro, [ 'ocorrencia_cidade','ocorrencia_uf']]
# Out:
#      ocorrencia_cidade ocorrencia_uf
# 7             CANUTAMA            AM
# 15            CANUTAMA            AM
# 408          NOVO GAMA            GO
# 688           BURITAMA            SP
# 1035          BURITAMA            SP
# 1377          UMUARAMA            PR
# 1401         AURIFLAMA            SP
# 2099         NOVA LIMA            MG
# 2102          CANUTAMA            AM
# 2646          IVINHEMA            MS
# 2657           DIADEMA            SP
# 2857              FAMA            MG
# 2968          BURITAMA            SP
# 2999          IVINHEMA            MS
# 3042         NOVA LIMA            MG
# 3094           ITAPEMA            SC
# 3159         PINDORAMA            SP
# 3173         PACARAIMA            RR
# 3191          UMUARAMA            PR
# 3684         NOVA LIMA            MG
# 3727         NOVA LIMA            MG
# 3883          BURITAMA            SP
# 4231          CANUTAMA            AM
# 4313           ITAPEMA            SC
# 4576           ITAPEMA            SC
# 4987           IRACEMA            RR
# 5071          CANUTAMA            AM
# 5081          IVINHEMA            MS
# 5406           ITURAMA            MG
# 5441          IVINHEMA            MS
# 5475           IBIRAMA            SC
# 5759           IRACEMA            RR
# 5776         NOVA LIMA            MG
# 5778         NOVA LIMA            MG
# 5861         IBOTIRAMA            BA
# 6093          UMUARAMA            PR

# %%
filtro = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro, [ 'ocorrencia_cidade','ocorrencia_uf']]
# Out:
#        ocorrencia_cidade ocorrencia_uf
# 7               CANUTAMA            AM
# 13    PRIMAVERA DO LESTE            MT
# 15              CANUTAMA            AM
# 35                PALMAS            TO
# 78                MANAUS            AM
# ...                  ...           ...
# 6075              MANAUS            AM
# 6086               AMAPÁ            AP
# 6090               MARAÚ            BA
# 6093            UMUARAMA            PR
# 6106              MANAUS            AM
#
# [514 rows x 2 columns]

# %% [markdown]
# filtrando por data

# %%
filtro = df.ocorrencia_dia.dt.year == 2018
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4304              77607               77607                INCIDENTE
# 4305              77608               77608          INCIDENTE GRAVE
# 4306              77610               77610          INCIDENTE GRAVE
# 4307              77616               77616          INCIDENTE GRAVE
# 4308              77617               77617                INCIDENTE
# ...                 ...                 ...                      ...
# 4743              78410               78410                INCIDENTE
# 4744              78390               78390                 ACIDENTE
# 4745              78433               78433                INCIDENTE
# 4746              78406               78406                INCIDENTE
# 4747              78394               78394                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4304      PORTO SEGURO            BA                 SBPS     2018-01-03
# 4305     ARROIO GRANDE            RS                  NaN     2018-01-03
# 4306    RIO DE JANEIRO            RJ                 SBGL     2018-01-04
# 4307      PORTO SEGURO            BA                  NaN     2018-01-04
# 4308      CAMPO GRANDE            AL                 SBCG     2018-01-04
# ...                ...           ...                  ...            ...
# 4743         GUARULHOS            SP                 SBGR     2018-12-27
# 4744           ARACAJU            SE                  NaN     2018-12-29
# 4745          CURITIBA            PR                 SBCT     2018-12-29
# 4746         GUARULHOS            SP                  NaN     2018-12-30
# 4747      CALDAS NOVAS            GO                  NaN     2018-12-31
#
#      ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 4304        11:36:00                    0 NaN          NaN          NaN
# 4305        13:51:00                    0 NaN          NaN          NaN
# 4306        23:38:00                    0 NaN          NaN          NaN
# 4307        20:45:00                    0 NaN          NaN          NaN
# 4308        20:44:00                    0 NaN          NaN          NaN
# ...              ...                  ...  ..          ...          ...
# 4743        03:15:00                    0 NaN          NaN          NaN
# 4744        15:30:00                    1 NaN          NaN          NaN
# 4745        14:30:00                    0 NaN          NaN          NaN
# 4746        17:30:00                    0 NaN          NaN          NaN
# 4747        11:50:00                    0 NaN          NaN          NaN
#
#       Unnamed: 12 Unnamed: 13
# 4304          NaN         NaN
# 4305          NaN         NaN
# 4306          NaN         NaN
# 4307          NaN         NaN
# 4308          NaN         NaN
# ...           ...         ...
# 4743          NaN         NaN
# 4744          NaN         NaN
# 4745          NaN         NaN
# 4746          NaN         NaN
# 4747          NaN         NaN
#
# [444 rows x 14 columns]

# %% [markdown]
# juntar duas colunas de tipos diferentes

# %%
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)
