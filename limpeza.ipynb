# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates = ['ocorrencia_dia'], dayfirst=True)
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 0        12:00:00                    0 NaN          NaN          NaN
# 1        11:05:00                    0 NaN          NaN          NaN
# 2        03:00:00                    0 NaN          NaN          NaN
# 3        17:30:00                    0 NaN          NaN          NaN
# 4        19:25:00                    0 NaN          NaN          NaN
#
#    Unnamed: 12 Unnamed: 13
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN

# %% [markdown]
# pegando os dados de linha e coluna especificas

# %%
df.loc[1, 'ocorrencia_uf']
# Out:
# 'PA'

# %% [markdown]
# pegando diversas linhas

# %%
df.loc[1:4]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 1        11:05:00                    0 NaN          NaN          NaN
# 2        03:00:00                    0 NaN          NaN          NaN
# 3        17:30:00                    0 NaN          NaN          NaN
# 4        19:25:00                    0 NaN          NaN          NaN
#
#    Unnamed: 12 Unnamed: 13
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN

# %% [markdown]
# pegando toda a coluna

# %%
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %% [markdown]
# alterando o indice

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes      \
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00                    0 NaN
# 40349                 2010-01-03        11:05:00                    0 NaN
# 40351                 2010-01-03        03:00:00                    0 NaN
# 39527                 2010-01-04        17:30:00                    0 NaN
# 40324                 2010-01-05        19:25:00                    0 NaN
#
#                    Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# codigo_ocorrencia
# 40211                      NaN          NaN          NaN         NaN
# 40349                      NaN          NaN          NaN         NaN
# 40351                      NaN          NaN          NaN         NaN
# 39527                      NaN          NaN          NaN         NaN
# 40324                      NaN          NaN          NaN

# %% [markdown]
# vendo os dados de uma linha em especifico

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
#                                             NaN
# Unnamed: 10                                 NaN
# Unnamed: 11                                 NaN
# Unnamed: 12                                 NaN
# Unnamed: 13
# Name: 40324, dtype: object

# %% [markdown]
# voltando ao indece original

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes      Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0                    0 NaN          NaN          NaN          NaN         NaN
# 1                    0 NaN          NaN          NaN          NaN         NaN
# 2                    0 NaN          NaN          NaN          NaN         NaN
# 3                    0 NaN          NaN          NaN          NaN         NaN
# 4                    0 NaN          NaN          NaN          NaN

# %% [markdown]
# alterando o valor de um dado

# %%
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes      Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0                    0 NaN          NaN          NaN          NaN         NaN
# 1                    0 NaN          NaN          NaN          NaN         NaN
# 2                    0 NaN          NaN          NaN          NaN         NaN
# 3                    0 NaN          NaN          NaN          NaN         NaN
# 4                    0 NaN          NaN          NaN          NaN

# %% [markdown]
# alterando os dados de uma linha inteira

# %%
df.loc[1] = 38

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
# 1                  38                       38                38
#
#   ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0            RJ                       2010-01-03 00:00:00        12:00:00
# 1            38                   38                   38              38
#
#    total_recomendacoes        Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0                    0   NaN          NaN          NaN          NaN
# 1                   38  38.0         38.0         38.0         38.0
#
#   Unnamed: 13
# 0         NaN
# 1          38

# %% [markdown]
# alterando os dados de uma coluna inteira

# %%
df.loc[:, 'ocorrencia_classificacao'] = 'abcd'

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                     abcd      RIO DE JANEIRO
# 1                     38                     abcd                  38
# 2                  40351                     abcd      RIO DE JANEIRO
# 3                  39527                     abcd  LUCAS DO RIO VERDE
# 4                  40324                     abcd             PELOTAS
# ...                  ...                      ...                 ...
# 6109               80245                     abcd              RECIFE
# 6110               80247                     abcd         PORTO VELHO
# 6111               80251                     abcd               BELÉM
# 6112               80257                     abcd          DOM AQUINO
# 6113               80259                     abcd            CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 0               RJ                       2010-01-03 00:00:00        12:00:00
# 1               38                   38                   38              38
# 2               RJ                 SBRJ  2010-01-03 00:00:00        03:00:00
# 3               MT                 ****  2010-01-04 00:00:00        17:30:00
# 4               RS                 SBPK  2010-01-05 00:00:00        19:25:00
# ...            ...                  ...                  ...             ...
# 6109            PE                 SBRF  2021-08-15 00:00:00        15:05:00
# 6110            RO                 SBPV  2021-08-16 00:00:00        02:30:00
# 6111            PA                 SBBE  2021-08-17 00:00:00        15:45:00
# 6112            MT                 ****  2021-08-18 00:00:00        16:00:00
# 6113            SP                 SBKP  2021-08-18 00:00:00        12:45:00
#
#       total_recomendacoes        Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0                       0   NaN          NaN          NaN          NaN
# 1                      38  38.0         38.0         38.0         38.0
# 2                       0   NaN          NaN          NaN          NaN
# 3                       0   NaN          NaN          NaN          NaN
# 4                       0   NaN          NaN          NaN          NaN
# ...                   ...   ...          ...          ...          ...
# 6109                    0   NaN          NaN          NaN          NaN
# 6110                    0   NaN          NaN          NaN          NaN
# 6111                    0   NaN          NaN          NaN          NaN
# 6112                    0   NaN          NaN          NaN          NaN
# 6113                    0   NaN          NaN          NaN          NaN
#
#      Unnamed: 13
# 0            NaN
# 1             38
# 2            NaN
# 3            NaN
# 4
# ...          ...
# 6109         NaN
# 6110         NaN
# 6111         NaN
# 6112         NaN
# 6113         NaN
#
# [6114 rows x 13 columns]

# %% [markdown]
# criando backup de coluna

# %%
df.loc['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                             40211.0                     abcd
# 1                                38.0                     abcd
# 2                             40351.0                     abcd
# 3                             39527.0                     abcd
# 4                             40324.0                     abcd
# ...                               ...                      ...
# 6110                          80247.0                     abcd
# 6111                          80251.0                     abcd
# 6112                          80257.0                     abcd
# 6113                          80259.0                     abcd
# ocorrencia_uf_bkp                 NaN                      NaN
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0                      RIO DE JANEIRO            RJ
# 1                                  38            38                   38
# 2                      RIO DE JANEIRO            RJ                 SBRJ
# 3                  LUCAS DO RIO VERDE            MT                 ****
# 4                             PELOTAS            RS                 SBPK
# ...                               ...           ...                  ...
# 6110                      PORTO VELHO            RO                 SBPV
# 6111                            BELÉM            PA                 SBBE
# 6112                       DOM AQUINO            MT                 ****
# 6113                         CAMPINAS            SP                 SBKP
# ocorrencia_uf_bkp                 NaN           NaN                  NaN
#
#                         ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                  2010-01-03 00:00:00        12:00:00                  0.0
# 1                                   38              38                 38.0
# 2                  2010-01-03 00:00:00        03:00:00                  0.0
# 3                  2010-01-04 00:00:00        17:30:00                  0.0
# 4                  2010-01-05 00:00:00        19:25:00                  0.0
# ...                                ...             ...                  ...
# 6110               2021-08-16 00:00:00        02:30:00                  0.0
# 6111               2021-08-17 00:00:00        15:45:00                  0.0
# 6112               2021-08-18 00:00:00        16:00:00                  0.0
# 6113               2021-08-18 00:00:00        12:45:00                  0.0
# ocorrencia_uf_bkp                  NaN             NaN                  NaN
#
#                          Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0                   NaN          NaN          NaN          NaN         NaN
# 1                  38.0         38.0         38.0         38.0          38
# 2                   NaN          NaN          NaN          NaN         NaN
# 3                   NaN          NaN          NaN          NaN         NaN
# 4                   NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...         ...
# 6110                NaN          NaN          NaN          NaN         NaN
# 6111                NaN          NaN          NaN          NaN         NaN
# 6112                NaN          NaN          NaN          NaN         NaN
# 6113                NaN          NaN          NaN          NaN         NaN
# ocorrencia_uf_bkp   NaN          NaN          NaN          NaN         NaN
#
# [6115 rows x 13 columns]

# %% [markdown]
# filtrando dados e trocando valor de um campo

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] ='GRAVE'

# %%
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                             40211.0                     abcd
# 1                                38.0                     abcd
# 2                             40351.0                     abcd
# 3                             39527.0                     abcd
# 4                             40324.0                     abcd
# ...                               ...                      ...
# 6110                          80247.0                     abcd
# 6111                          80251.0                     abcd
# 6112                          80257.0                     abcd
# 6113                          80259.0                    GRAVE
# ocorrencia_uf_bkp                 NaN                      NaN
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0                      RIO DE JANEIRO            RJ
# 1                                  38            38                   38
# 2                      RIO DE JANEIRO            RJ                 SBRJ
# 3                  LUCAS DO RIO VERDE            MT                 ****
# 4                             PELOTAS            RS                 SBPK
# ...                               ...           ...                  ...
# 6110                      PORTO VELHO            RO                 SBPV
# 6111                            BELÉM            PA                 SBBE
# 6112                       DOM AQUINO            MT                 ****
# 6113                         CAMPINAS            SP                 SBKP
# ocorrencia_uf_bkp                 NaN           NaN                  NaN
#
#                         ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                  2010-01-03 00:00:00        12:00:00                  0.0
# 1                                   38              38                 38.0
# 2                  2010-01-03 00:00:00        03:00:00                  0.0
# 3                  2010-01-04 00:00:00        17:30:00                  0.0
# 4                  2010-01-05 00:00:00        19:25:00                  0.0
# ...                                ...             ...                  ...
# 6110               2021-08-16 00:00:00        02:30:00                  0.0
# 6111               2021-08-17 00:00:00        15:45:00                  0.0
# 6112               2021-08-18 00:00:00        16:00:00                  0.0
# 6113               2021-08-18 00:00:00        12:45:00                  0.0
# ocorrencia_uf_bkp                  NaN             NaN                  NaN
#
#                          Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0                   NaN          NaN          NaN          NaN         NaN
# 1                  38.0         38.0         38.0         38.0          38
# 2                   NaN          NaN          NaN          NaN         NaN
# 3                   NaN          NaN          NaN          NaN         NaN
# 4                   NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...         ...
# 6110                NaN          NaN          NaN          NaN         NaN
# 6111                NaN          NaN          NaN          NaN         NaN
# 6112                NaN          NaN          NaN          NaN         NaN
# 6113                NaN          NaN          NaN          NaN         NaN
# ocorrencia_uf_bkp   NaN          NaN          NaN          NaN         NaN
#
# [6115 rows x 13 columns]

# %% [markdown]
# filtrando linha por condicao

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao  ocorrencia_cidade  \
# 11               40069.0                    GRAVE          SÃO PAULO
# 16               39809.0                    GRAVE          SÃO PAULO
# 18               39828.0                    GRAVE             SANTOS
# 26               39847.0                    GRAVE           SOROCABA
# 27               39768.0                    GRAVE           CAMPINAS
# ...                  ...                      ...                ...
# 6084             80234.0                    GRAVE          SÃO PAULO
# 6085             80208.0                    GRAVE          SÃO PAULO
# 6104             80238.0                    GRAVE        VOTUPORANGA
# 6108             80244.0                    GRAVE  BRAGANÇA PAULISTA
# 6113             80259.0                    GRAVE           CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo       ocorrencia_dia ocorrencia_hora  \
# 11              SP                 SBMT  2010-01-10 00:00:00        14:50:00
# 16              SP                 ****  2010-01-15 00:00:00        15:00:00
# 18              SP                 ****  2010-01-15 00:00:00        17:45:00
# 26              SP                 ****  2010-01-20 00:00:00        13:10:00
# 27              SP                 ****  2010-01-21 00:00:00        20:45:00
# ...            ...                  ...                  ...             ...
# 6084            SP                 SBSP  2021-07-26 00:00:00        13:20:00
# 6085            SP                 SBMT  2021-07-27 00:00:00        19:45:00
# 6104            SP                 SDVG  2021-08-11 00:00:00        19:09:00
# 6108            SP                 SBBP  2021-08-15 00:00:00        15:20:00
# 6113            SP                 SBKP  2021-08-18 00:00:00        12:45:00
#
#       total_recomendacoes      Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 11                    8.0 NaN          NaN          NaN          NaN
# 16                    0.0 NaN          NaN          NaN          NaN
# 18                    0.0 NaN          NaN          NaN          NaN
# 26                    0.0 NaN          NaN          NaN          NaN
# 27                    0.0 NaN          NaN          NaN          NaN
# ...                   ...  ..          ...          ...          ...
# 6084                  0.0 NaN          NaN          NaN          NaN
# 6085                  0.0 NaN          NaN          NaN          NaN
# 6104                  0.0 NaN          NaN          NaN          NaN
# 6108                  0.0 NaN          NaN          NaN          NaN
# 6113                  0.0 NaN          NaN          NaN          NaN
#
#      Unnamed: 13
# 11           NaN
# 16           NaN
# 18           NaN
# 26           NaN
# 27           NaN
# ...          ...
# 6084         NaN
# 6085         NaN
# 6104         NaN
# 6108         NaN
# 6113         NaN
#
# [1464 rows x 13 columns]

# %%
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                             40211.0                     abcd
# 1                                38.0                     abcd
# 2                             40351.0                     abcd
# 3                             39527.0                     abcd
# 4                             40324.0                     abcd
# ...                               ...                      ...
# 6110                          80247.0                     abcd
# 6111                          80251.0                     abcd
# 6112                          80257.0                     abcd
# 6113                          80259.0                    GRAVE
# ocorrencia_uf_bkp                 NaN                      NaN
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0                      RIO DE JANEIRO            RJ
# 1                                  38            38                   38
# 2                      RIO DE JANEIRO            RJ                 SBRJ
# 3                  LUCAS DO RIO VERDE            MT                 ****
# 4                             PELOTAS            RS                 SBPK
# ...                               ...           ...                  ...
# 6110                      PORTO VELHO            RO                 SBPV
# 6111                            BELÉM            PA                 SBBE
# 6112                       DOM AQUINO            MT                 ****
# 6113                         CAMPINAS            SP                 SBKP
# ocorrencia_uf_bkp                 NaN           NaN                  NaN
#
#                         ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                  2010-01-03 00:00:00        12:00:00                  0.0
# 1                                   38              38                 38.0
# 2                  2010-01-03 00:00:00        03:00:00                  0.0
# 3                  2010-01-04 00:00:00        17:30:00                  0.0
# 4                  2010-01-05 00:00:00        19:25:00                  0.0
# ...                                ...             ...                  ...
# 6110               2021-08-16 00:00:00        02:30:00                  0.0
# 6111               2021-08-17 00:00:00        15:45:00                  0.0
# 6112               2021-08-18 00:00:00        16:00:00                  0.0
# 6113               2021-08-18 00:00:00        12:45:00                  0.0
# ocorrencia_uf_bkp                  NaN             NaN                  NaN
#
#                          Unnamed: 10  Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0                   NaN          NaN          NaN          NaN         NaN
# 1                  38.0         38.0         38.0         38.0          38
# 2                   NaN          NaN          NaN          NaN         NaN
# 3                   NaN          NaN          NaN          NaN         NaN
# 4                   NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...         ...
# 6110                NaN          NaN          NaN          NaN         NaN
# 6111                NaN          NaN          NaN          NaN         NaN
# 6112                NaN          NaN          NaN          NaN         NaN
# 6113                NaN          NaN          NaN          NaN         NaN
# ocorrencia_uf_bkp   NaN          NaN          NaN          NaN         NaN
#
# [6115 rows x 13 columns]

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 6109              RECIFE            PE                 SBRF     2021-08-15
# 6110         PORTO VELHO            RO                 SBPV     2021-08-16
# 6111               BELÉM            PA                 SBBE     2021-08-17
# 6112          DOM AQUINO            MT                 ****     2021-08-18
# 6113            CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 0           12:00:00                    0 NaN          NaN          NaN
# 1           11:05:00                    0 NaN          NaN          NaN
# 2           03:00:00                    0 NaN          NaN          NaN
# 3           17:30:00                    0 NaN          NaN          NaN
# 4           19:25:00                    0 NaN          NaN          NaN
# ...              ...                  ...  ..          ...          ...
# 6109        15:05:00                    0 NaN          NaN          NaN
# 6110        02:30:00                    0 NaN          NaN          NaN
# 6111        15:45:00                    0 NaN          NaN          NaN
# 6112        16:00:00                    0 NaN          NaN          NaN
# 6113        12:45:00                    0 NaN          NaN          NaN
#
#       Unnamed: 12 Unnamed: 13
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN
# ...           ...         ...
# 6109          NaN         NaN
# 6110          NaN         NaN
# 6111          NaN         NaN
# 6112          NaN         NaN
# 6113          NaN         NaN
#
# [6114 rows x 14 columns]

# %% [markdown]
# limpando e substituindo **** por <NA>

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0            40211.0             40211.0                INCIDENTE
# 1            40349.0             40349.0                INCIDENTE
# 2            40351.0             40351.0                INCIDENTE
# 3            39527.0             39527.0                 ACIDENTE
# 4            40324.0             40324.0                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 <NA>     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 0        12:00:00                  0.0 NaN          NaN          NaN
# 1        11:05:00                  0.0 NaN          NaN          NaN
# 2        03:00:00                  0.0 NaN          NaN          NaN
# 3        17:30:00                  0.0 NaN          NaN          NaN
# 4        19:25:00                  0.0 NaN          NaN          NaN
#
#    Unnamed: 12 Unnamed: 13
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN

# %% [markdown]
# substituindo todos os nulos de uma vez

# %%
df.replace(['**', '###!', '####', '****', '*****', 'NULL'], pd.NA, inplace=True)

# %%
df
# Out:
#                               codigo_ocorrencia  codigo_ocorrencia2  \
# 0                                       40211.0             40211.0
# 1                                       40349.0             40349.0
# 2                                       40351.0             40351.0
# 3                                       39527.0             39527.0
# 4                                       40324.0             40324.0
# ...                                         ...                 ...
# 6110                                    80247.0             80247.0
# 6111                                    80251.0             80251.0
# 6112                                    80257.0             80257.0
# 6113                                    80259.0             80259.0
# ocorrencia_aerodromo == ****                NaN                 NaN
#
#                              ocorrencia_classificacao   ocorrencia_cidade  \
# 0                                           INCIDENTE      RIO DE JANEIRO
# 1                                           INCIDENTE               BELÉM
# 2                                           INCIDENTE      RIO DE JANEIRO
# 3                                            ACIDENTE  LUCAS DO RIO VERDE
# 4                                           INCIDENTE             PELOTAS
# ...                                               ...                 ...
# 6110                                        INCIDENTE         PORTO VELHO
# 6111                                        INCIDENTE               BELÉM
# 6112                                         ACIDENTE          DOM AQUINO
# 6113                                        INCIDENTE            CAMPINAS
# ocorrencia_aerodromo == ****                      NaN                 NaN
#
#                              ocorrencia_uf ocorrencia_aerodromo  \
# 0                                       RJ                 <NA>
# 1                                       PA                 SBBE
# 2                                       RJ                 SBRJ
# 3                                       MT                 <NA>
# 4                                       RS                 SBPK
# ...                                    ...                  ...
# 6110                                    RO                 SBPV
# 6111                                    PA                 SBBE
# 6112                                    MT                 <NA>
# 6113                                    SP                 SBKP
# ocorrencia_aerodromo == ****           NaN                 <NA>
#
#                              ocorrencia_dia ocorrencia_hora  \
# 0                                2010-01-03        12:00:00
# 1                                2010-01-03        11:05:00
# 2                                2010-01-03        03:00:00
# 3                                2010-01-04        17:30:00
# 4                                2010-01-05        19:25:00
# ...                                     ...             ...
# 6110                             2021-08-16        02:30:00
# 6111                             2021-08-17        15:45:00
# 6112                             2021-08-18        16:00:00
# 6113                             2021-08-18        12:45:00
# ocorrencia_aerodromo == ****            NaT             NaN
#
#                               total_recomendacoes      Unnamed: 10  \
# 0                                             0.0 NaN          NaN
# 1                                             0.0 NaN          NaN
# 2                                             0.0 NaN          NaN
# 3                                             0.0 NaN          NaN
# 4                                             0.0 NaN          NaN
# ...                                           ...  ..          ...
# 6110                                          0.0 NaN          NaN
# 6111                                          0.0 NaN          NaN
# 6112                                          0.0 NaN          NaN
# 6113                                          0.0 NaN          NaN
# ocorrencia_aerodromo == ****                  NaN NaN          NaN
#
#                               Unnamed: 11  Unnamed: 12 Unnamed: 13
# 0                                     NaN          NaN         NaN
# 1                                     NaN          NaN         NaN
# 2                                     NaN          NaN         NaN
# 3                                     NaN          NaN         NaN
# 4                                     NaN          NaN
# ...                                   ...          ...         ...
# 6110                                  NaN          NaN         NaN
# 6111                                  NaN          NaN         NaN
# 6112                                  NaN          NaN         NaN
# 6113                                  NaN          NaN         NaN
# ocorrencia_aerodromo == ****          NaN          NaN         NaN
#
# [6115 rows x 14 columns]

# %% [markdown]
# somar por coluna quantos dados não informados por coluna tem

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              1
# codigo_ocorrencia2             1
# ocorrencia_classificacao       1
# ocorrencia_cidade              1
# ocorrencia_uf                  3
# ocorrencia_aerodromo        2457
# ocorrencia_dia                 1
# ocorrencia_hora                2
# total_recomendacoes            1
#                             6115
# Unnamed: 10                 6115
# Unnamed: 11                 6115
# Unnamed: 12                 6115
# Unnamed: 13                 6114
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              1
# codigo_ocorrencia2             1
# ocorrencia_classificacao       1
# ocorrencia_cidade              1
# ocorrencia_uf                  3
# ocorrencia_aerodromo        2457
# ocorrencia_dia                 1
# ocorrencia_hora                2
# total_recomendacoes            1
#                             6115
# Unnamed: 10                 6115
# Unnamed: 11                 6115
# Unnamed: 12                 6115
# Unnamed: 13                 6114
# dtype: int64

# %% [markdown]
# adicionar valor a todos os dados não informados

# %%
df.fillna(4, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
#                             0
# Unnamed: 10                 0
# Unnamed: 11                 0
# Unnamed: 12                 0
# Unnamed: 13                 0
# dtype: int64

# %% [markdown]
# voltando valores para NA

# %%
df.replace([4], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              1
# codigo_ocorrencia2             1
# ocorrencia_classificacao       1
# ocorrencia_cidade              1
# ocorrencia_uf                  3
# ocorrencia_aerodromo        2457
# ocorrencia_dia                 1
# ocorrencia_hora                2
# total_recomendacoes           51
#                             6115
# Unnamed: 10                 6115
# Unnamed: 11                 6115
# Unnamed: 12                 6115
# Unnamed: 13                 6114
# dtype: int64

# %% [markdown]
# trocando valor NA de apenas uma coluna

# %%
df.fillna(value={'total_recomendacoes':4}, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              1
# codigo_ocorrencia2             1
# ocorrencia_classificacao       1
# ocorrencia_cidade              1
# ocorrencia_uf                  3
# ocorrencia_aerodromo        2457
# ocorrencia_dia                 1
# ocorrencia_hora                2
# total_recomendacoes            0
#                             6115
# Unnamed: 10                 6115
# Unnamed: 11                 6115
# Unnamed: 12                 6115
# Unnamed: 13                 6114
# dtype: int64

# %% [markdown]
# excluindo coluna

# %%
df.drop(['Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'], axis=1, inplace=True)

# %%
df
# Out:
#                              codigo_ocorrencia codigo_ocorrencia2  \
# 0                                      40211.0            40211.0
# 1                                      40349.0            40349.0
# 2                                      40351.0            40351.0
# 3                                      39527.0            39527.0
# 4                                      40324.0            40324.0
# ...                                        ...                ...
# 6110                                   80247.0            80247.0
# 6111                                   80251.0            80251.0
# 6112                                   80257.0            80257.0
# 6113                                   80259.0            80259.0
# ocorrencia_aerodromo == ****              <NA>               <NA>
#
#                              ocorrencia_classificacao   ocorrencia_cidade  \
# 0                                           INCIDENTE      RIO DE JANEIRO
# 1                                           INCIDENTE               BELÉM
# 2                                           INCIDENTE      RIO DE JANEIRO
# 3                                            ACIDENTE  LUCAS DO RIO VERDE
# 4                                           INCIDENTE             PELOTAS
# ...                                               ...                 ...
# 6110                                        INCIDENTE         PORTO VELHO
# 6111                                        INCIDENTE               BELÉM
# 6112                                         ACIDENTE          DOM AQUINO
# 6113                                        INCIDENTE            CAMPINAS
# ocorrencia_aerodromo == ****                     <NA>                <NA>
#
#                              ocorrencia_uf ocorrencia_aerodromo  \
# 0                                       RJ                 <NA>
# 1                                       PA                 SBBE
# 2                                       RJ                 SBRJ
# 3                                       MT                 <NA>
# 4                                       RS                 SBPK
# ...                                    ...                  ...
# 6110                                    RO                 SBPV
# 6111                                    PA                 SBBE
# 6112                                    MT                 <NA>
# 6113                                    SP                 SBKP
# ocorrencia_aerodromo == ****          <NA>                 <NA>
#
#                                    ocorrencia_dia ocorrencia_hora  \
# 0                             2010-01-03 00:00:00        12:00:00
# 1                             2010-01-03 00:00:00        11:05:00
# 2                             2010-01-03 00:00:00        03:00:00
# 3                             2010-01-04 00:00:00        17:30:00
# 4                             2010-01-05 00:00:00        19:25:00
# ...                                           ...             ...
# 6110                          2021-08-16 00:00:00        02:30:00
# 6111                          2021-08-17 00:00:00        15:45:00
# 6112                          2021-08-18 00:00:00        16:00:00
# 6113                          2021-08-18 00:00:00        12:45:00
# ocorrencia_aerodromo == ****                 <NA>            <NA>
#
#                               total_recomendacoes
# 0                                             0.0  <NA>
# 1                                             0.0  <NA>
# 2                                             0.0  <NA>
# 3                                             0.0  <NA>
# 4                                             0.0  <NA>
# ...                                           ...   ...
# 6110                                          0.0  <NA>
# 6111                                          0.0  <NA>
# 6112                                          0.0  <NA>
# 6113                                          0.0  <NA>
# ocorrencia_aerodromo == ****                  4.0  <NA>
#
# [6115 rows x 10 columns]

# %%
df.drop(['ocorrencia_aerodromo == ****'], inplace=True)

# %%
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211.0            40211.0                INCIDENTE
# 1              40349.0            40349.0                INCIDENTE
# 2              40351.0            40351.0                INCIDENTE
# 3              39527.0            39527.0                 ACIDENTE
# 4              40324.0            40324.0                INCIDENTE
# ...                ...                ...                      ...
# 6109           80245.0            80245.0                INCIDENTE
# 6110           80247.0            80247.0                INCIDENTE
# 6111           80251.0            80251.0                INCIDENTE
# 6112           80257.0            80257.0                 ACIDENTE
# 6113           80259.0            80259.0                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 0         RIO DE JANEIRO            RJ                 <NA>
# 1                  BELÉM            PA                 SBBE
# 2         RIO DE JANEIRO            RJ                 SBRJ
# 3     LUCAS DO RIO VERDE            MT                 <NA>
# 4                PELOTAS            RS                 SBPK
# ...                  ...           ...                  ...
# 6109              RECIFE            PE                 SBRF
# 6110         PORTO VELHO            RO                 SBPV
# 6111               BELÉM            PA                 SBBE
# 6112          DOM AQUINO            MT                 <NA>
# 6113            CAMPINAS            SP                 SBKP
#
#            ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0     2010-01-03 00:00:00        12:00:00                  0.0  <NA>
# 1     2010-01-03 00:00:00        11:05:00                  0.0  <NA>
# 2     2010-01-03 00:00:00        03:00:00                  0.0  <NA>
# 3     2010-01-04 00:00:00        17:30:00                  0.0  <NA>
# 4     2010-01-05 00:00:00        19:25:00                  0.0  <NA>
# ...                   ...             ...                  ...   ...
# 6109  2021-08-15 00:00:00        15:05:00                  0.0  <NA>
# 6110  2021-08-16 00:00:00        02:30:00                  0.0  <NA>
# 6111  2021-08-17 00:00:00        15:45:00                  0.0  <NA>
# 6112  2021-08-18 00:00:00        16:00:00                  0.0  <NA>
# 6113  2021-08-18 00:00:00        12:45:00                  0.0  <NA>
#
# [6114 rows x 10 columns]

# %% [markdown]
# excluindo valores duplicados

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1                  BELÉM            PA                 SBBE     2010-01-03
# 2         RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4                PELOTAS            RS                 SBPK     2010-01-05
# ...                  ...           ...                  ...            ...
# 6109              RECIFE            PE                 SBRF     2021-08-15
# 6110         PORTO VELHO            RO                 SBPV     2021-08-16
# 6111               BELÉM            PA                 SBBE     2021-08-17
# 6112          DOM AQUINO            MT                 ****     2021-08-18
# 6113            CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes      Unnamed: 10  Unnamed: 11  \
# 0           12:00:00                    0 NaN          NaN          NaN
# 1           11:05:00                    0 NaN          NaN          NaN
# 2           03:00:00                    0 NaN          NaN          NaN
# 3           17:30:00                    0 NaN          NaN          NaN
# 4           19:25:00                    0 NaN          NaN          NaN
# ...              ...                  ...  ..          ...          ...
# 6109        15:05:00                    0 NaN          NaN          NaN
# 6110        02:30:00                    0 NaN          NaN          NaN
# 6111        15:45:00                    0 NaN          NaN          NaN
# 6112        16:00:00                    0 NaN          NaN          NaN
# 6113        12:45:00                    0 NaN          NaN          NaN
#
#       Unnamed: 12 Unnamed: 13
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN
# ...           ...         ...
# 6109          NaN         NaN
# 6110          NaN         NaN
# 6111          NaN         NaN
# 6112          NaN         NaN
# 6113          NaN         NaN
#
# [6114 rows x 14 columns]
